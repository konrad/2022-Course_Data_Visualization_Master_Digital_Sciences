# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.palplot?

# %%
sns.palplot(sns.color_palette("rocket", 20))

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights, cmap="BrBG_r")

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")



for colormap in ["rocket", "BrBG_r", "BuGn", "rocket_r", "hot_r", "magma_r", "plasma_r"]:
    fig = plt.figure()
    ax = sns.heatmap(flights, cmap=colormap)

# %%
import numpy as np
random_data = np.random.randn(10, 10)
ax = sns.heatmap(random_data, cmap="Spectral")

# %%
for colormap in ["Spectral", "coolwarm", "inferno"]:
    sns.palplot(sns.color_palette(colormap, 20))

# %%
for colormap in ["Spectral", "coolwarm", "BrBG_r", "twilight_shifted", "twilight_shifted_r"]:
    fig = plt.figure()
    ax = sns.heatmap(random_data, cmap=colormap)
